# %%
import pandas as pd

# %%
file = 'Resources/veterans_pop_loc_v2.csv'
df = pd.read_csv(file)
df.head()
# Out:
#    Unnamed: 0 State   County   Latitude  Longitude  TotalVets  MaleVets  \
# 0           0    AL  Alabama  32.601011 -86.680736     330207    296507
# 1           1    AL  Autauga  32.601011 -86.680736       5272      4599
# 2           2    AL  Baldwin  32.601011 -86.680736      19663     18118
# 3           3    AL  Barbour  32.601011 -86.680736       1328      1222
# 4           4    AL     Bibb  32.601011 -86.680736       1433      1373
#
#    FemaleVets  WhiteVets  BlackVets  HispanicVets  OtherRaceVets  \
# 0       33699     239513      75768          6676          10102
# 1         672       4429        509           294             59
# 2        1544      17819       1054           283            575
# 3         104        790        495            14             41
# 4          59       1133        264            33              0
#
#    LessThanHSVets  HighSchOnlyVets  SomeCollegeVets  CollegeDegreeVets  \
# ...

# %%
df_1 = df.drop([0,68,102,118,194,253,318,331,333,401,561,567,612,715,808,908,1014,
               1135,1200,1217,1242,1257,1341,1429,1512,1628,1685,1779,1797,1808,1830,
               1864,1927,2028,2082,2171,2249,2286,2354,2360,2407,2474,2570,2825,
               2855,2870,3005,3045,3101,3174])
df_1.head()
# Out:
#    Unnamed: 0 State   County   Latitude  Longitude  TotalVets  MaleVets  \
# 1           1    AL  Autauga  32.601011 -86.680736       5272      4599
# 2           2    AL  Baldwin  32.601011 -86.680736      19663     18118
# 3           3    AL  Barbour  32.601011 -86.680736       1328      1222
# 4           4    AL     Bibb  32.601011 -86.680736       1433      1373
# 5           5    AL   Blount  32.601011 -86.680736       3417      3136
#
#    FemaleVets  WhiteVets  BlackVets  HispanicVets  OtherRaceVets  \
# 1         672       4429        509           294             59
# 2        1544      17819       1054           283            575
# 3         104        790        495            14             41
# 4          59       1133        264            33              0
# 5         281       3221         44           102            102
#
#    LessThanHSVets  HighSchOnlyVets  SomeCollegeVets  CollegeDegreeVets  \
# ...

# %%
df_1.to_csv('Resources/veterans_pop_loc_v3.csv', encoding='utf-8')
