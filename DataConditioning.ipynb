# %%
import pandas as pd
from utils_common import get_db_engine
import re

# Suppresses the GPU-related warning messages that TensorFlow produces
import warnings
warnings.filterwarnings('ignore')

# %%
def drop_summary_rows(df):
# Data contains state-level summaries, identified by the County showing the full State name.
# This removes those rows.
    for (idx, row) in df_states.iterrows():
        state, code = row.loc[['State', 'Code']]
        droprow = df.loc[(df['County'] == state) & (df['State'] == code)].index
        df = df.drop(droprow)
    return df

# %%
def percent_to_num(df, pct_column, num_column, pop_column):
    df[num_column] = round((df[pct_column] * df[pop_column] / 100),0)
    df = df.drop(pct_column, axis=1)
    return df

# %%
# Redundant or troublesome once it's been rolled into Final Project
try:
    db_engine = get_db_engine()
except Exception as e:
    print(f"\nFailed to connect to database engine.\n", e)

# %%
file_states = 'Resources/States.csv'
df_states = pd.read_csv(file_states)
df_states.to_sql(name='states', con=db_engine, if_exists='replace', index=False)
df_states.head()
# Out:
#         State Code
# 0     Alabama   AL
# 1      Alaska   AK
# 2     Arizona   AZ
# 3    Arkansas   AR
# 4  California   CA

# %%
file_vet_pop = 'Resources/veterans_pop_loc.csv'
df_vet_pop = pd.read_csv(file_vet_pop)
df_vet_pop.to_sql(name='vet_pop_unconditioned', con=db_engine, if_exists='replace', index=False)

# %%
df_vet_pop = df_vet_pop.drop('Unnamed: 0', axis=1)

# %%
df_vet_pop = drop_summary_rows(df_vet_pop)
df_vet_pop.fillna(0)
# Out:
#      State      County   Latitude   Longitude  TotalVets  \
# 1       AL     Autauga  32.601011  -86.680736     5272.0
# 2       AL     Baldwin  32.601011  -86.680736    19663.0
# 3       AL     Barbour  32.601011  -86.680736     1328.0
# 4       AL        Bibb  32.601011  -86.680736     1433.0
# 5       AL      Blount  32.601011  -86.680736     3417.0
# ...    ...         ...        ...         ...        ...
# 3193    WY  Sweetwater  43.000325 -107.554567     2749.0
# 3194    WY       Teton  43.000325 -107.554567      999.0
# 3195    WY       Uinta  43.000325 -107.554567     1069.0
# 3196    WY    Washakie  43.000325 -107.554567      719.0
# 3197    WY      Weston  43.000325 -107.554567      576.0
#
#       VeteranPopulationPct  MaleVetsPct  FemaleVetsPct  WhiteVetsPct  \
# 1                12.635111    87.253414      12.746586     84.028832
# 2                11.815500    92.147689       7.852311     90.621980
# 3                 6.622120    92.093373       7.906627     59.563253
# 4                 8.022618    95.882763       4.117237     79.134682
# 5                 7.720813    91.776412       8.223588     94.293240
# ...                    ...          ...            ...           ...
# 3193              8.599224    94.579847       5.420153     90.360131
# 3194              5.301985    87.787788      12.212212     97.497497
# 3195              7.379029    92.609916       7.390084     93.732460
# 3196             11.902003    96.244784       3.755216     95.410292
# 3197             10.346686    90.104167       9.895833     94.444444
#
#       BlackVetsPct  HispanicVetsPct  OtherRaceVetsPct  LessThanHSVetsPct  \
# 1         9.673748         5.576631          1.119120           3.007812
# 2         5.360321         1.439251          2.929360           3.612916
# 3        37.349398         1.054217          3.087349          12.349398
# 4        18.492673         2.372645          0.000000           6.901510
# 5         1.287679         2.985075          2.985075          11.655901
# ...            ...              ...               ...                ...
# 3193      0.363769         8.766824          2.946526           2.301411
# 3194      0.000000         0.000000          2.502503           3.219316
# 3195      1.028999         1.216090          4.022451           4.209542
# 3196      0.000000         4.589708          0.000000          14.186370
# 3197      0.000000         2.430556          3.125000           3.405018
#
#       HighSchOnlyVetsPct  SomeCollegeVetsPct  CollegeDegreeVetsPct  \
# 1              20.859375           31.621094             44.511719
# 2              27.659792           36.676731             32.050560
# 3              39.834337           36.746988             11.069277
# 4              54.708843           22.286125             16.103523
# 5              33.734586           38.667058             15.942454
# ...                  ...                 ...                   ...
# 3193           32.516704           49.962880             15.219005
# 3194           27.565392           15.291750             53.923541
# 3195           29.092610           40.692236             26.005613
# 3196           36.022253           26.842837             22.948540
# 3197           42.831541           36.738351             17.025090
#
#       EmployeedVetsPct  UnemployeedVetsPct
# 1            86.549340            3.558460
# 2            74.927707            3.430532
# 3            49.752066            9.966777
# 4            56.901408            0.000000
# 5            64.528302            7.309942
# ...                ...                 ...
# 3193         91.394865            2.581625
# 3194         79.680365            0.000000
# 3195         74.569790            0.769231
# 3196         85.585586            0.000000
# 3197         71.532847           10.204082
#
# [3139 rows x 18 columns]

# %%
pct_columns = ['MaleVetsPct', 'FemaleVetsPct', 'WhiteVetsPct',
               'BlackVetsPct', 'HispanicVetsPct', 'OtherRaceVetsPct', 'LessThanHSVetsPct',
               'HighSchOnlyVetsPct', 'SomeCollegeVetsPct', 'CollegeDegreeVetsPct',
               'EmployeedVetsPct', 'UnemployeedVetsPct'] 
pop_column = 'TotalVets'

for col in pct_columns:
    num_col = re.sub('Pct', '', col, count=0, flags=0)
    df_vet_pop = percent_to_num(df_vet_pop, col, num_col, pop_column)

# Drop the VetPct. We could derive total population from here, but we're already pulling it
# in underived from the People table.
df_vet_pop = df_vet_pop.drop('VeteranPopulationPct', axis=1)

# %%
df_vet_pop.head()
# Out:
#   State   County   Latitude  Longitude  TotalVets  MaleVets  FemaleVets  \
# 1    AL  Autauga  32.601011 -86.680736     5272.0    4600.0       672.0
# 2    AL  Baldwin  32.601011 -86.680736    19663.0   18119.0      1544.0
# 3    AL  Barbour  32.601011 -86.680736     1328.0    1223.0       105.0
# 4    AL     Bibb  32.601011 -86.680736     1433.0    1374.0        59.0
# 5    AL   Blount  32.601011 -86.680736     3417.0    3136.0       281.0
#
#    WhiteVets  BlackVets  HispanicVets  OtherRaceVets  LessThanHSVets  \
# 1     4430.0      510.0         294.0           59.0           159.0
# 2    17819.0     1054.0         283.0          576.0           710.0
# 3      791.0      496.0          14.0           41.0           164.0
# 4     1134.0      265.0          34.0            0.0            99.0
# 5     3222.0       44.0         102.0          102.0           398.0
#
#    HighSchOnlyVets  SomeCollegeVets  CollegeDegreeVets  EmployeedVets  \
# 1           1100.0           1667.0             2347.0         4563.0
# 2           5439.0           7212.0             6302.0        14733.0
# 3            529.0            488.0              147.0          661.0
# 4            784.0            319.0              231.0          815.0
# 5           1153.0           1321.0              545.0         2205.0
#
#    UnemployeedVets
# 1            188.0
# 2            675.0
# 3            132.0
# 4              0.0
# 5            250.0

# %%
df_vet_pop.to_sql(name='vet_population', con=db_engine, if_exists='replace', index=False)

# %%
file_people = 'Resources/People.csv'
df_people = pd.read_csv(file_people)
df_people.to_sql(name='people_unconditioned', con=db_engine, if_exists='replace', index=False)

# %%
df_people = drop_summary_rows(df_people)
df_people.head()
# Out:
#    FIPS State   County  PopChangeRate1819  PopChangeRate1019  TotalPopEst2019  \
# 1  1001    AL  Autauga              0.605              2.001            55869
# 2  1003    AL  Baldwin              2.469             21.911           223234
# 3  1005    AL  Barbour             -0.748             -9.664            24686
# 4  1007    AL     Bibb              0.121             -2.081            22394
# 5  1009    AL   Blount              0.095              0.784            57826
#
#    NetMigrationRate1019  NaturalChangeRate1019  \
# 1                 0.686                  1.315
# 2                21.001                  0.910
# 3                -8.797                 -0.867
# 4                -2.099                  0.017
# 5                -0.005                  0.790
#
#    Net_International_Migration_Rate_2010_2019  PopChangeRate0010  ...  \
# 1                                      -0.029              24.96  ...
# 2                                       0.714              29.80  ...
# 3                                       0.161              -5.44  ...
# 4                                       0.525              10.03  ...
# 5                                       0.207              12.34  ...
#
#    TotalPopEst2014  TotalPopEst2011  Net_International_Migration_2010_2019  \
# 1            54893            55227                                  -16.0
# 2           199183           186558                                 1307.0
# 3            26755            27341                                   44.0
# 4            22553            22745                                  120.0
# 5            57526            57560                                  119.0
#
#    NaturalChange1019  TotalPopEst2015  TotalPopEst2016  TotalPopEst2017  \
# 1              720.0            54864            55243            55390
# 2             1667.0           202939           207601           212521
# 3             -237.0            26283            25806            25157
# 4                4.0            22566            22586            22550
# 5              453.0            57526            57494            57787
#
#    NetMigration1019  TotalPopEst2018  TotalPopEstBase2010
# 1             376.0            55533                54597
# 2           38455.0           217855               182265
# 3           -2404.0            24872                27455
# 4            -480.0            22367                22915
# 5              -3.0            57771                57322
#
# [5 rows x 91 columns]

# %%
df_reduced_people = df_people[['State','County','TotalPopEst2015','TotalPopEst2016','TotalPopEst2017',
                              'TotalPopEst2018','TotalPopEst2019']]

# %%
df_reduced_people.fillna(0)
# Out:
#      State     County  TotalPopEst2015  TotalPopEst2016  TotalPopEst2017  \
# 1       AL    Autauga            54864            55243            55390
# 2       AL    Baldwin           202939           207601           212521
# 3       AL    Barbour            26283            25806            25157
# 4       AL       Bibb            22566            22586            22550
# 5       AL     Blount            57526            57494            57787
# ...    ...        ...              ...              ...              ...
# 3266    PR  Vega Baja            54805            53677            52318
# 3267    PR    Vieques             8965             8833             8666
# 3268    PR   Villalba            23662            23091            22452
# 3269    PR    Yabucoa            35076            34363            33519
# 3270    PR      Yauco            37585            36654            35474
#
#       TotalPopEst2018  TotalPopEst2019
# 1               55533            55869
# 2              217855           223234
# 3               24872            24686
# 4               22367            22394
# 5               57771            57826
# ...               ...              ...
# 3266            50136            50023
# 3267             8362             8386
# 3268            21436            21372
# 3269            32254            32282
# 3270            33853            33575
#
# [3212 rows x 7 columns]

# %%
df_reduced_people['AveragePop2015to2019'] = df_reduced_people.mean(axis=1)

# %%
df_reduced_people.to_sql(name='reduced_people', con=db_engine, if_exists='replace', index=False)
